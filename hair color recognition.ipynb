# %%
from IPython.display import Image
import cv2
import numpy as np
from matplotlib import pyplot as plt
Image(filename='ins2.jpg')

# %%
Image(filename='ins2-2.jpg')

# %%
img = cv2.imread('ins2-2.jpg')
means = cv2.mean(img)
means
average_color_per_row = np.average(img, axis=0)
average_color = np.average(average_color_per_row, axis=0)
average_color2 = np.uint8(average_color)
print(average_color2)
average_color_img = np.array([[average_color]*100]*100, np.uint8)
plt.imshow(average_color_img)
# Out:
# [81 81 89]

# %%
Image(filename='ins3-3.jpg')

# %%
img = cv2.imread('ins3-3.jpg')
means = cv2.mean(img)
means
average_color_per_row = np.average(img, axis=0)
average_color = np.average(average_color_per_row, axis=0)
average_color3 = np.uint8(average_color)
print(average_color3)
average_color_img = np.array([[average_color]*100]*100, np.uint8)
plt.imshow(average_color_img)
# Out:
# [115  98 122]

# %%
Image(filename='ins4-4.jpg')

# %%
img = cv2.imread('ins4-4.jpg')
means = cv2.mean(img)
means
average_color_per_row = np.average(img, axis=0)
average_color = np.average(average_color_per_row, axis=0)
average_color4 = np.uint8(average_color)
print(average_color4)
average_color_img = np.array([[average_color]*100]*100, np.uint8)
plt.imshow(average_color_img)
# Out:
# [146 156 168]

# %%
Image(filename='ins5-5.jpg')

# %%
img = cv2.imread('ins5-5.jpg')
means = cv2.mean(img)
means
average_color_per_row = np.average(img, axis=0)
average_color = np.average(average_color_per_row, axis=0)
average_color5 = np.uint8(average_color)
print(average_color5)
average_color_img = np.array([[average_color]*100]*100, np.uint8)
plt.imshow(average_color_img)
# Out:
# [ 87  78 143]

# %%
Image(filename='ins9-9.jpg')

# %%
img = cv2.imread('ins9-9.jpg')
means = cv2.mean(img)
means
average_color_per_row = np.average(img, axis=0)
average_color = np.average(average_color_per_row, axis=0)
average_color9 = np.uint8(average_color)
print(average_color9)
average_color_img = np.array([[average_color]*100]*100, np.uint8)
plt.imshow(average_color_img)
# Out:
# [49 41 46]

# %%
Image(filename='ins10-10.jpg')

# %%
img = cv2.imread('ins10-10.jpg')
means = cv2.mean(img)
means
average_color_per_row = np.average(img, axis=0)
average_color = np.average(average_color_per_row, axis=0)
average_color10 = np.uint8(average_color)
print(average_color10)
average_color_img = np.array([[average_color]*100]*100, np.uint8)
plt.imshow(average_color_img)
# Out:
# [64 26 92]

# %%
mean=(average_color2+average_color3+average_color4+average_color5+average_color9+average_color10)/6
print(mean)
# Out:
# [ 2.16666667 28.16666667 25.16666667]
